# %%
import json
from logpy import Relation, facts, run, conde, var, eq
def parent(x,y):
    return conde([father(x,y)],[mother(x,y)])
def grandparent(x,y):
    temp=var()
    return conde((parent(x,temp),parent(temp,y)))
def sibling(x,y):
    temp=var()
    return conde((parent(temp,x), parent(temp,y)))
def uncle(x,y):
    temp=var()
    return conde((father(temp,x),grandparent(temp,y)))
if __name__=='__main__':
    father=Relation()
    mother=Relation()
    with open('relationship.json') as f:
        d=json.loads(f.read())
    for item in d['father']:
        facts(father, (list(item.keys()) [0],list(item.values()) [0] ))
    for item in d['mother']:
        facts(mother, (list(item.keys()) [0],list(item.values()) [0] ))
    x=var()
    name='subbaroa'
    output=run(0,x,father(name,x))
    print("\nList of " + name + "'s children:")
    for item in output:
        print(item)
    name='gupta'
    output=run(0,x,father(name,x))
    print("\nList of " + name + "'s children:")
    for item in output:
        print(item)
    name='vijay'
    output=run(0,x,father(name,x))
    print("\nList of " + name + "'s children:")
    for item in output:
        print(item)
    name='uma'
    output=run(0,x,mother(x,name))[0]
    print("\n " + name + "'s mother:\n"+output)
    name='gupta'
    output=run(0,x,parent(x,name))
    print("\nList of " + name + "'s parents:")
    for item in output:
        print(item)
    name='uma'
    output=run(0,x,parent(x,name))
    print("\nList of " + name + "'s parents:")
    for item in output:
        print(item)
    name='praveen'
    output=run(0,x,grandparent(x,name))
    print("\nList of " + name + "'s grandparents:")
    for item in output:
        print(item)
    name='alekhya'
    output=run(0,x,grandparent(x,name))
    print("\nList of " + name + "'s grandparents:")
    for item in output:
        print(item)
    name='masthanama'
    output=run(0,x,grandparent(name,x))
    print("\nList of " + name + "'s grandchildren:")
    for item in output:
        print(item)
    name='sai'
    output=run(0,x,sibling(x,name))
    siblings=[x for x in output if x!=name]
    print("\nList of"+ name +"'siblings:")
    for item in siblings:
        print(item)
    name='alekhya'
    output=run(0,x,sibling(x,name))
    siblings=[x for x in output if x!=name]
    print("\nList of"+ name +"'siblings:")
    for item in siblings:
        print(item)
    name='anusha'
    name_father=run(0,x,father(x,name))[0]
    output=run(0,x,uncle(x,name))
    output=[x for x in output if x!=name_father]
    print("\nList of" + name + "'s uncles:")
    for item in output:
        print(item)
    name='akhil'
    name_father=run(0,x,father(x,name))[0]
    output=run(0,x,uncle(x,name))
    output=[x for x in output if x!=name_father]
    print("\nList of" + name + "'s uncles:")
    for item in output:
        print(item)
    a,b,c=var(),var(),var()
    output=run(0,(a,b),(father,a,c),(mother,b,c))
    print("\nList of all spouses:")
    for item in output:
        print('Husband:',item[0],'<==> Wife:',item[1])
# Out:
# List of subbaroa's children:
# vijay
# uma
# sai
# gupta
#
# List of gupta's children:
# siri
# chandhu
#
# List of vijay's children:
# alekhya
# akhil
#
#  uma's mother:
# masthanama
#
# List of gupta's parents:
# subbaroa
# masthanama
#
# List of uma's parents:
# subbaroa
# masthanama
#
# List of praveen's grandparents:
# masthanama
# subbaroa
#
# List of alekhya's grandparents:
# subbaroa
# masthanama
#
# List of masthanama's grandchildren:
# siri
# anusha
# mounica
# alekhya
# chandhu
# praveen
# shyam
# akhil
#
# List ofsai'siblings:
# vijay
# uma
# gupta
#
# List ofalekhya'siblings:
# akhil
#
# List ofanusha's uncles:
# vijay
# uma
# gupta
#
# List ofakhil's uncles:
# uma
# sai
# gupta
#
# List of all spouses:
# Husband: subbaroa <==> Wife: masthanama
# Husband: uma <==> Wife: vani
# Husband: vijay <==> Wife: bhavani
# Husband: gupta <==> Wife: lakshmi
# Husband: sai <==> Wife: rani
